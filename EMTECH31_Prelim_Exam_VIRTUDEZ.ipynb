# %% [markdown]
# <a href="https://colab.research.google.com/github/keirvirtudez/CPE-018-CPE31S2/blob/main/EMTECH31_Prelim_Exam_VIRTUDEZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRELIM EXAMINATION**
#
# Virtudez, Renmar Keir F.\
# CPE018 - CPE31S2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **NUMBER 1**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image_path = '/content/drive/MyDrive/EMTECH/nature.jpg'

img = cv2.imread(image_path)

# %% [markdown]
# **NUMBER 2**

# %%
if img is not None:
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    plt.imshow(img, cmap='gray')
    plt.title('Converted to Grayscale Image')
    plt.axis('off')
    plt.show()

# %% [markdown]
# **NUMBER 3**

# %%
img_path = '/content/drive/MyDrive/EMTECH/nature.jpg'

img = cv2.resize(img, (300, 300))

plt.imshow(img, cmap='gray')
plt.title('Resized Image')
plt.axis('off')
plt.show()

# %% [markdown]
# **NUMBER 4**

# %%
from google.colab.patches import cv2_imshow

save_path = '/content/drive/MyDrive/EMTECH/nature_resized.jpg'

cv2.imwrite(save_path, img)
processed_image = cv2.imread(save_path)
cv2_imshow(processed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
